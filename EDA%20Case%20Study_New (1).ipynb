# %% [markdown]
# ### <font color = maroon> 1. Importing required libraries </font>

# %%
# Filtering out the warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # <font color = blue> EDA Case Study </font>

# %% [markdown]
# This case study aims to identify patterns which indicate if a client has difficulty paying their installments which may be used for taking actions such as denying the loan, reducing the amount of loan, lending (to risky applicants) at a higher interest rate, etc. This will ensure that the consumers capable of repaying the loan are not rejected. Identification of such applicants using EDA is the aim of this case study.

# %% [markdown]
# ### <font color = maroon> 2. Reading and cleaning the data from Application Data</font>

# %%
# reading data from csv for both previous application & current application data
appData_df =pd.read_csv('application_data.csv')

# %% [markdown]
# #### <font color = maroon> 2.1 Checking structure of application_data </font>

# %%
# checking for the shape/ row & columns in current application

appData_df.shape
# Out:
# (307511, 122)

# %%
# checking for the description of dataframe for all numeric values

appData_df.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# 50%    5.135310e+05   24903.000000     4.500000e+05
# 75%    8.086500e+05   34596.000000     6.795000e+05
# max    4.050000e+06  258025.500000     4.050000e+06
#
#        REGION_POPULATION_RELATIVE     DAYS_BIRTH  DAYS_EMPLOYED  ...  \
# count               307511.000000  307511.000000  307511.000000  ...
# mean                     0.020868  -16036.995067   63815.045904  ...
# std                      0.013831    4363.988632  141275.766519  ...
# min                      0.000290  -25229.000000  -17912.000000  ...
# 25%                      0.010006  -19682.000000   -2760.000000  ...
# 50%                      0.018850  -15750.000000   -1213.000000  ...
# 75%                      0.028663  -12413.000000    -289.000000  ...
# max                      0.072508   -7489.000000  365243.000000  ...
#
#        FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# count     307511.000000     307511.000000     307511.000000     307511.000000
# mean           0.008130          0.000595          0.000507          0.000335
# std            0.089798          0.024387          0.022518          0.018299
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# count               265992.000000              265992.000000
# mean                     0.006402                   0.007000
# std                      0.083849                   0.110757
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      4.000000                   9.000000
#
#        AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# count               265992.000000              265992.000000
# mean                     0.034362                   0.267395
# std                      0.204685                   0.916002
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      8.000000                  27.000000
#
#        AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# count              265992.000000               265992.000000
# mean                    0.265474                    1.899974
# std                     0.794056                    1.869295
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    1.000000
# 75%                     0.000000                    3.000000
# max                   261.000000                   25.000000
#
# [8 rows x 106 columns]

# %%
# checking for null values in all columns

appData_df.isnull().sum()
# Out:
# SK_ID_CURR                        0
# TARGET                            0
# NAME_CONTRACT_TYPE                0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
#                               ...
# AMT_REQ_CREDIT_BUREAU_DAY     41519
# AMT_REQ_CREDIT_BUREAU_WEEK    41519
# AMT_REQ_CREDIT_BUREAU_MON     41519
# AMT_REQ_CREDIT_BUREAU_QRT     41519
# AMT_REQ_CREDIT_BUREAU_YEAR    41519
# Length: 122, dtype: int64

# %% [markdown]
# #### <font color = maroon> 2.2 Dropping unwanted columns</font>

# %% [markdown]
# Dropping columns having null data more than or equal to 35%, we increased this from earlier planned 30% as one of the column OCCUPATION_TYPE was having around 31% null values which is very important for this analysis

# %%
# fetching the columns having null values greater than or equal 35%

colWithHighNullValues = (appData_df.isnull().sum()/len(appData_df))
colWithHighNullValues = list(colWithHighNullValues[colWithHighNullValues.values>=0.35].index)
appData_df.drop(labels = colWithHighNullValues,axis =1,inplace=True)

# %%
# rechecking the shape of dataframe if columns have reduced
appData_df.shape
# Out:
# (307511, 73)

# %% [markdown]
# Dropping columns related to "FLAG_" and "EXT_"

# %%
# dropping columns starting with FLAG_ and EXT_ as they are not needed for further analysis

column_list=[]
for i in appData_df.columns:
    if not ((i.startswith('FLAG_')) | (i.startswith('EXT_'))):
        column_list.append(i)
        
        
appData_df = appData_df.loc[:, column_list]

# %%
# rechecking the shape of dataframe

appData_df.shape
# Out:
# (307511, 43)

# %%
# getting info of the dataframe 

appData_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   SK_ID_CURR                   307511 non-null  int64
#  1   TARGET                       307511 non-null  int64
#  2   NAME_CONTRACT_TYPE           307511 non-null  object
#  3   CODE_GENDER                  307511 non-null  object
#  4   CNT_CHILDREN                 307511 non-null  int64
#  5   AMT_INCOME_TOTAL             307511 non-null  float64
#  6   AMT_CREDIT                   307511 non-null  float64
#  7   AMT_ANNUITY                  307499 non-null  float64
#  8   AMT_GOODS_PRICE              307233 non-null  float64
#  9   NAME_TYPE_SUITE              306219 non-null  object
#  10  NAME_INCOME_TYPE             307511 non-null  object
#  11  NAME_EDUCATION_TYPE          307511 non-null  object
#  12  NAME_FAMILY_STATUS           307511 non-null  object
#  13  NAME_HOUSING_TYPE            307511 non-null  object
#  14  REGION_POPULATION_RELATIVE   307511 non-null  float64
#  15  DAYS_BIRTH                   307511 non-null  int64
#  16  DAYS_EMPLOYED                307511 non-null  int64
#  17  DAYS_REGISTRATION            307511 non-null  float64
#  18  DAYS_ID_PUBLISH              307511 non-null  int64
#  19  OCCUPATION_TYPE              211120 non-null  object
#  20  CNT_FAM_MEMBERS              307509 non-null  float64
#  21  REGION_RATING_CLIENT         307511 non-null  int64
#  22  REGION_RATING_CLIENT_W_CITY  307511 non-null  int64
#  23  WEEKDAY_APPR_PROCESS_START   307511 non-null  object
#  24  HOUR_APPR_PROCESS_START      307511 non-null  int64
#  25  REG_REGION_NOT_LIVE_REGION   307511 non-null  int64
#  26  REG_REGION_NOT_WORK_REGION   307511 non-null  int64
#  27  LIVE_REGION_NOT_WORK_REGION  307511 non-null  int64
#  28  REG_CITY_NOT_LIVE_CITY       307511 non-null  int64
#  29  REG_CITY_NOT_WORK_CITY       307511 non-null  int64
#  30  LIVE_CITY_NOT_WORK_CITY      307511 non-null  int64
#  31  ORGANIZATION_TYPE            307511 non-null  object
#  32  OBS_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  33  DEF_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  34  OBS_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  35  DEF_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  36  DAYS_LAST_PHONE_CHANGE       307510 non-null  float64
#  37  AMT_REQ_CREDIT_BUREAU_HOUR   265992 non-null  float64
#  38  AMT_REQ_CREDIT_BUREAU_DAY    265992 non-null  float64
#  39  AMT_REQ_CREDIT_BUREAU_WEEK   265992 non-null  float64
#  40  AMT_REQ_CREDIT_BUREAU_MON    265992 non-null  float64
#  41  AMT_REQ_CREDIT_BUREAU_QRT    265992 non-null  float64
#  42  AMT_REQ_CREDIT_BUREAU_YEAR   265992 non-null  float64
# dtypes: float64(18), int64(15), object(10)
# memory usage: 100.9+ MB

# %%
# having a check again on the columns having null values

appData_df.isnull().sum().sort_values(ascending = False)
# Out:
# OCCUPATION_TYPE                96391
# AMT_REQ_CREDIT_BUREAU_YEAR     41519
# AMT_REQ_CREDIT_BUREAU_MON      41519
# AMT_REQ_CREDIT_BUREAU_WEEK     41519
# AMT_REQ_CREDIT_BUREAU_DAY      41519
# AMT_REQ_CREDIT_BUREAU_HOUR     41519
# AMT_REQ_CREDIT_BUREAU_QRT      41519
# NAME_TYPE_SUITE                 1292
# OBS_30_CNT_SOCIAL_CIRCLE        1021
# DEF_30_CNT_SOCIAL_CIRCLE        1021
# OBS_60_CNT_SOCIAL_CIRCLE        1021
# DEF_60_CNT_SOCIAL_CIRCLE        1021
# AMT_GOODS_PRICE                  278
# AMT_ANNUITY                       12
# CNT_FAM_MEMBERS                    2
# DAYS_LAST_PHONE_CHANGE             1
# NAME_FAMILY_STATUS                 0
# NAME_EDUCATION_TYPE                0
# NAME_INCOME_TYPE                   0
# CODE_GENDER                        0
# AMT_CREDIT                         0
# AMT_INCOME_TOTAL                   0
# CNT_CHILDREN                       0
# REGION_POPULATION_RELATIVE         0
# NAME_CONTRACT_TYPE                 0
# TARGET                             0
# NAME_HOUSING_TYPE                  0
# REGION_RATING_CLIENT               0
# DAYS_BIRTH                         0
# DAYS_EMPLOYED                      0
# DAYS_REGISTRATION                  0
# DAYS_ID_PUBLISH                    0
# REGION_RATING_CLIENT_W_CITY        0
# WEEKDAY_APPR_PROCESS_START         0
# HOUR_APPR_PROCESS_START            0
# REG_REGION_NOT_LIVE_REGION         0
# REG_REGION_NOT_WORK_REGION         0
# LIVE_REGION_NOT_WORK_REGION        0
# REG_CITY_NOT_LIVE_CITY             0
# REG_CITY_NOT_WORK_CITY             0
# LIVE_CITY_NOT_WORK_CITY            0
# ORGANIZATION_TYPE                  0
# SK_ID_CURR                         0
# dtype: int64

# %% [markdown]
# #### <font color = maroon> 2.3 Further Imputation and cleaning of columns</font>
#
# Based on the null value count, here is the plan we are following

# %%
#OCCUPATION_TYPE                96391 --> replace with value "Unknown" as value is high we do not want to directly umpute here
#AMT_REQ_CREDIT_BUREAU_YEAR     41519 --> drop 
#AMT_REQ_CREDIT_BUREAU_MON      41519 --> drop
#AMT_REQ_CREDIT_BUREAU_WEEK     41519 --> drop
#AMT_REQ_CREDIT_BUREAU_DAY      41519 --> drop
#AMT_REQ_CREDIT_BUREAU_HOUR     41519 --> drop
#AMT_REQ_CREDIT_BUREAU_QRT      41519 --> drop
#NAME_TYPE_SUITE                 1292 --> replace with mode Unaccompanied      
#OBS_30_CNT_SOCIAL_CIRCLE        1021 --> no action will be taken
#DEF_30_CNT_SOCIAL_CIRCLE        1021 --> no action will be taken
#OBS_60_CNT_SOCIAL_CIRCLE        1021 --> no action will be taken
#DEF_60_CNT_SOCIAL_CIRCLE        1021 --> no action will be taken
#AMT_GOODS_PRICE                  278 --> replace with median
#AMT_ANNUITY                       12 --> replace with median
#CNT_FAM_MEMBERS                    2 --> replace with mode
#DAYS_LAST_PHONE_CHANGE             1 --> replace with median

# %%
# replacing all null values in "Occupation Type" with "Unknown"

appData_df["OCCUPATION_TYPE"].fillna("Unknown", inplace=True)

# %%
# reprinting all the null values present in dataset

appData_df.isnull().sum().sort_values(ascending = False)
# Out:
# AMT_REQ_CREDIT_BUREAU_YEAR     41519
# AMT_REQ_CREDIT_BUREAU_MON      41519
# AMT_REQ_CREDIT_BUREAU_WEEK     41519
# AMT_REQ_CREDIT_BUREAU_DAY      41519
# AMT_REQ_CREDIT_BUREAU_HOUR     41519
# AMT_REQ_CREDIT_BUREAU_QRT      41519
# NAME_TYPE_SUITE                 1292
# OBS_30_CNT_SOCIAL_CIRCLE        1021
# DEF_30_CNT_SOCIAL_CIRCLE        1021
# OBS_60_CNT_SOCIAL_CIRCLE        1021
# DEF_60_CNT_SOCIAL_CIRCLE        1021
# AMT_GOODS_PRICE                  278
# AMT_ANNUITY                       12
# CNT_FAM_MEMBERS                    2
# DAYS_LAST_PHONE_CHANGE             1
# NAME_HOUSING_TYPE                  0
# NAME_FAMILY_STATUS                 0
# NAME_EDUCATION_TYPE                0
# NAME_INCOME_TYPE                   0
# CODE_GENDER                        0
# AMT_CREDIT                         0
# AMT_INCOME_TOTAL                   0
# CNT_CHILDREN                       0
# DAYS_BIRTH                         0
# NAME_CONTRACT_TYPE                 0
# TARGET                             0
# REGION_POPULATION_RELATIVE         0
# REGION_RATING_CLIENT               0
# DAYS_EMPLOYED                      0
# DAYS_REGISTRATION                  0
# DAYS_ID_PUBLISH                    0
# OCCUPATION_TYPE                    0
# REGION_RATING_CLIENT_W_CITY        0
# WEEKDAY_APPR_PROCESS_START         0
# HOUR_APPR_PROCESS_START            0
# REG_REGION_NOT_LIVE_REGION         0
# REG_REGION_NOT_WORK_REGION         0
# LIVE_REGION_NOT_WORK_REGION        0
# REG_CITY_NOT_LIVE_CITY             0
# REG_CITY_NOT_WORK_CITY             0
# LIVE_CITY_NOT_WORK_CITY            0
# ORGANIZATION_TYPE                  0
# SK_ID_CURR                         0
# dtype: int64

# %% [markdown]
# Dropping columns having null data more than or equal to 10%, this we targeted to remove below columns as we believe for
# further analysis below data is no more required

# %%
#AMT_REQ_CREDIT_BUREAU_MON      41519
#AMT_REQ_CREDIT_BUREAU_WEEK     41519
#AMT_REQ_CREDIT_BUREAU_DAY      41519
#AMT_REQ_CREDIT_BUREAU_HOUR     41519
#AMT_REQ_CREDIT_BUREAU_QRT      41519

colWithHighNullValues = (appData_df.isnull().sum()/len(appData_df))
colWithHighNullValues = list(colWithHighNullValues[colWithHighNullValues.values>=0.1].index)
appData_df.drop(labels = colWithHighNullValues,axis =1,inplace=True)

# %%
# checking the shape of data 

appData_df.shape
# Out:
# (307511, 37)

# %%
# imputations done on other null values present application data

appData_df["AMT_ANNUITY"].fillna(appData_df["AMT_ANNUITY"].median(), inplace=True)
appData_df["AMT_GOODS_PRICE"].fillna(appData_df["AMT_GOODS_PRICE"].median(), inplace=True)
appData_df["CNT_FAM_MEMBERS"].fillna(appData_df["CNT_FAM_MEMBERS"].mode()[0], inplace=True)
appData_df["DAYS_LAST_PHONE_CHANGE"].fillna(appData_df["DAYS_LAST_PHONE_CHANGE"].mean(), inplace=True)
appData_df["NAME_TYPE_SUITE"].fillna(appData_df["NAME_TYPE_SUITE"].mode()[0], inplace=True)

# %%
appData_df.isnull().sum().sort_values(ascending = False)
# Out:
# OBS_60_CNT_SOCIAL_CIRCLE       1021
# DEF_30_CNT_SOCIAL_CIRCLE       1021
# OBS_30_CNT_SOCIAL_CIRCLE       1021
# DEF_60_CNT_SOCIAL_CIRCLE       1021
# DAYS_LAST_PHONE_CHANGE            0
# AMT_GOODS_PRICE                   0
# NAME_HOUSING_TYPE                 0
# NAME_FAMILY_STATUS                0
# NAME_EDUCATION_TYPE               0
# NAME_INCOME_TYPE                  0
# NAME_TYPE_SUITE                   0
# AMT_CREDIT                        0
# AMT_ANNUITY                       0
# DAYS_BIRTH                        0
# AMT_INCOME_TOTAL                  0
# CNT_CHILDREN                      0
# CODE_GENDER                       0
# NAME_CONTRACT_TYPE                0
# TARGET                            0
# REGION_POPULATION_RELATIVE        0
# DAYS_ID_PUBLISH                   0
# DAYS_EMPLOYED                     0
# DAYS_REGISTRATION                 0
# OCCUPATION_TYPE                   0
# CNT_FAM_MEMBERS                   0
# REGION_RATING_CLIENT              0
# REGION_RATING_CLIENT_W_CITY       0
# WEEKDAY_APPR_PROCESS_START        0
# HOUR_APPR_PROCESS_START           0
# REG_REGION_NOT_LIVE_REGION        0
# REG_REGION_NOT_WORK_REGION        0
# LIVE_REGION_NOT_WORK_REGION       0
# REG_CITY_NOT_LIVE_CITY            0
# REG_CITY_NOT_WORK_CITY            0
# LIVE_CITY_NOT_WORK_CITY           0
# ORGANIZATION_TYPE                 0
# SK_ID_CURR                        0
# dtype: int64

# %%
appData_df.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307511.000000     3.075110e+05
# mean   5.990260e+05   27108.487841     5.383163e+05
# std    4.024908e+05   14493.461065     3.692890e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# 50%    5.135310e+05   24903.000000     4.500000e+05
# 75%    8.086500e+05   34596.000000     6.795000e+05
# max    4.050000e+06  258025.500000     4.050000e+06
#
#        REGION_POPULATION_RELATIVE     DAYS_BIRTH  DAYS_EMPLOYED  ...  \
# count               307511.000000  307511.000000  307511.000000  ...
# mean                     0.020868  -16036.995067   63815.045904  ...
# std                      0.013831    4363.988632  141275.766519  ...
# min                      0.000290  -25229.000000  -17912.000000  ...
# 25%                      0.010006  -19682.000000   -2760.000000  ...
# 50%                      0.018850  -15750.000000   -1213.000000  ...
# 75%                      0.028663  -12413.000000    -289.000000  ...
# max                      0.072508   -7489.000000  365243.000000  ...
#
#        REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# count               307511.000000                307511.000000
# mean                     0.050769                     0.040659
# std                      0.219526                     0.197499
# min                      0.000000                     0.000000
# 25%                      0.000000                     0.000000
# 50%                      0.000000                     0.000000
# 75%                      0.000000                     0.000000
# max                      1.000000                     1.000000
#
#        REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# count           307511.000000           307511.000000
# mean                 0.078173                0.230454
# std                  0.268444                0.421124
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                0.000000
# max                  1.000000                1.000000
#
#        LIVE_CITY_NOT_WORK_CITY  OBS_30_CNT_SOCIAL_CIRCLE  \
# count            307511.000000             306490.000000
# mean                  0.179555                  1.422245
# std                   0.383817                  2.400989
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  2.000000
# max                   1.000000                348.000000
#
#        DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# count             306490.000000             306490.000000
# mean                   0.143421                  1.405292
# std                    0.446698                  2.379803
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  2.000000
# max                   34.000000                344.000000
#
#        DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE
# count             306490.000000           307511.000000
# mean                   0.100049             -962.858788
# std                    0.362291              826.807143
# min                    0.000000            -4292.000000
# 25%                    0.000000            -1570.000000
# 50%                    0.000000             -757.000000
# 75%                    0.000000             -274.000000
# max                   24.000000                0.000000
#
# [8 rows x 27 columns]

# %%
# CODE_GENDER & ORGANIZATION_TYPE value XNA to be replace with mode value from their respective columns

appData_df.loc[appData_df.CODE_GENDER == 'XNA','CODE_GENDER'] = appData_df.CODE_GENDER.mode()[0]
appData_df.loc[appData_df.ORGANIZATION_TYPE == 'XNA','ORGANIZATION_TYPE'] = appData_df.ORGANIZATION_TYPE.mode()[0]

# %%
# all negative values for DAY_* columns to be replaced with abs() values for easier analysis
column_list=[]
for i in appData_df.columns:
    if  i.startswith('DAYS_'):
        column_list.append(i)
        
        
appData_df[column_list]= abs(appData_df[column_list])

# %%
# Calculating Age of Applicants, by creating a new column "Age"

appData_df["Age"] = (appData_df["DAYS_BIRTH"] / 365).astype(int)

# %%
# printing information of all columns 

appData_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   SK_ID_CURR                   307511 non-null  int64
#  1   TARGET                       307511 non-null  int64
#  2   NAME_CONTRACT_TYPE           307511 non-null  object
#  3   CODE_GENDER                  307511 non-null  object
#  4   CNT_CHILDREN                 307511 non-null  int64
#  5   AMT_INCOME_TOTAL             307511 non-null  float64
#  6   AMT_CREDIT                   307511 non-null  float64
#  7   AMT_ANNUITY                  307511 non-null  float64
#  8   AMT_GOODS_PRICE              307511 non-null  float64
#  9   NAME_TYPE_SUITE              307511 non-null  object
#  10  NAME_INCOME_TYPE             307511 non-null  object
#  11  NAME_EDUCATION_TYPE          307511 non-null  object
#  12  NAME_FAMILY_STATUS           307511 non-null  object
#  13  NAME_HOUSING_TYPE            307511 non-null  object
#  14  REGION_POPULATION_RELATIVE   307511 non-null  float64
#  15  DAYS_BIRTH                   307511 non-null  float64
#  16  DAYS_EMPLOYED                307511 non-null  float64
#  17  DAYS_REGISTRATION            307511 non-null  float64
#  18  DAYS_ID_PUBLISH              307511 non-null  float64
#  19  OCCUPATION_TYPE              307511 non-null  object
#  20  CNT_FAM_MEMBERS              307511 non-null  float64
#  21  REGION_RATING_CLIENT         307511 non-null  int64
#  22  REGION_RATING_CLIENT_W_CITY  307511 non-null  int64
#  23  WEEKDAY_APPR_PROCESS_START   307511 non-null  object
#  24  HOUR_APPR_PROCESS_START      307511 non-null  int64
#  25  REG_REGION_NOT_LIVE_REGION   307511 non-null  int64
#  26  REG_REGION_NOT_WORK_REGION   307511 non-null  int64
#  27  LIVE_REGION_NOT_WORK_REGION  307511 non-null  int64
#  28  REG_CITY_NOT_LIVE_CITY       307511 non-null  int64
#  29  REG_CITY_NOT_WORK_CITY       307511 non-null  int64
#  30  LIVE_CITY_NOT_WORK_CITY      307511 non-null  int64
#  31  ORGANIZATION_TYPE            307511 non-null  object
#  32  OBS_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  33  DEF_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  34  OBS_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  35  DEF_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  36  DAYS_LAST_PHONE_CHANGE       307511 non-null  float64
#  37  Age                          307511 non-null  int32
# dtypes: float64(15), int32(1), int64(12), object(10)
# memory usage: 88.0+ MB

# %% [markdown]
# #### <font color = maroon> 2.4 Checking for outliers </font>

# %%
#identifying some of the columns with outliers in the application data

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Outlier Detections', fontsize=18)


amt_annual_income= sns.boxplot(appData_df['AMT_INCOME_TOTAL'], ax=axes[0])
amt_annual_income.set_xlabel('Annual Income of Applicants',fontsize= 12)

amt_credit= sns.boxplot(appData_df['AMT_CREDIT'], ax=axes[1])
amt_credit.set_xlabel('Amount Credited',fontsize= 12)


plt.show()

# %% [markdown]
# ### Observations:

# %% [markdown]
# - For **AMT_INCOME_TOTAL** column it can be seen that the IQR is itself not visible and a value is way higher.
# What we see in here are only the whisker values
# - Also for' **AMT_CREDIT** can be seen that Upper Fence has lot many values which determines it has outliers

# %% [markdown]
# #### <font color = maroon> 2.5 Checking distributions of values for all non-numeric columns </font>

# %%
# generic method to plot distributions for application data

def checkDistributionsFor(param):
    plt.figure(figsize=(14, 10))
    plt.title('Distribution of Applicants in terms of their ' + param, fontsize=18)
    sortedData = appData_df[param].value_counts().sort_values()
    sortedData.plot(kind='barh')
    plt.show()

# %% [markdown]
# ##### <font color = brown> 2.5.1 Distribution of Applicants in terms of their Occuption - Type</font>

# %%
checkDistributionsFor('OCCUPATION_TYPE')

# %% [markdown]
# ##### <font color = brown> 2.5.2 Distribution of DAYS when Applicant had started Previous Application</font>

# %%
checkDistributionsFor('WEEKDAY_APPR_PROCESS_START')

# %% [markdown]
# ##### <font color = brown> 2.5.3 Distribution of Applicants Organization Type</font>

# %%
checkDistributionsFor('ORGANIZATION_TYPE')

# %% [markdown]
# ##### <font color = brown> 2.5.4 Distribution of Applicants companion while coming for application</font>

# %%
checkDistributionsFor('NAME_TYPE_SUITE')

# %% [markdown]
# ##### <font color = brown> 2.5.5 Distribution of Applicants INCOME TYPE </font>

# %%
checkDistributionsFor('NAME_INCOME_TYPE')

# %% [markdown]
# ##### <font color = brown> 2.5.6 Distribution of Applicants Family Status </font>

# %%
checkDistributionsFor('NAME_FAMILY_STATUS')

# %% [markdown]
# ##### <font color = brown> 2.5.7 Distribution of Applicants Housing Situation </font>

# %%
checkDistributionsFor('NAME_HOUSING_TYPE')

# %% [markdown]
# ##### <font color = brown> 2.5.8 Distribution of Applicants Contract product type </font>

# %%
checkDistributionsFor('NAME_CONTRACT_TYPE')

# %% [markdown]
# ##### <font color = brown> 2.5.9 Distribution of Applicants Gender </font>

# %%
checkDistributionsFor('CODE_GENDER')

# %% [markdown]
# #### <font color = maroon> 2.6 Binning Values </font>

# %%
# Binning values For Applicants Income & Age as it will infer more meaning insights.
# We have done binning here with terms of research from Google on how in Indian different icome group exists.

appData_df['INCOME_GROUP'] = pd.qcut(appData_df.AMT_INCOME_TOTAL, q=[0, 0.2, 0.6, 0.9, 0.99, 1], 
                                      labels=['LOW', 'MIDDLE', 'RICH', 'VERY_RICH', 'ELITE'])

appData_df['Age_Group'] = pd.cut(appData_df.Age, bins=[0,19,39,59,100], 
                                  labels=["Teen", "Young Adults", "Old Adults","Senior Citizens"])

# %% [markdown]
# ##### <font color = maroon> 2.6.1 Checking for distribution of "Income Group" after binning </font>

# %%
checkDistributionsFor('INCOME_GROUP')

# %% [markdown]
# ##### <font color = maroon> 2.6.2 Checking for distribution of "Age Group" after binning </font>

# %%
checkDistributionsFor('Age_Group')

# %% [markdown]
# ### Observations
#
# - Maximum distribution in terms of **OCCUPATION TYPE** are of type **Unknown** which means the field is not mandatory while application is submitted. Should ask the management to take a decision on making this field mandatory, While least are of type **IT Staff**.
# - On **Weekdays** especially on **Tuesdays** the loan process starts at a higher rate than on **Weekends**.
# - Maximum distribution of **Organization Type** for the applicants are of type **Business Entity Type 3**.
# - Mostly the applicants are **Unaccompanied** while coming for submitting application.
# - Highest distribution of **Income Type** are of type **Working** class while least are in class **MATERNITY Leave, Unemployed, Student**
# - Mostly **Married** prople goes into process of availing loans.
# - Popular **Contract Type** are of type **Cash loans** as compared to **Revolving loans**
# - Mostly loans are availed by **Females**.
# - Mostly loans are availed by people in the age group **Young Adults** or more precisely between age **20  and 39**

# %% [markdown]
# #### <font color = maroon> 2.7 Target Imbalance Check </font>

# %%
# Having a check of columns with aggregation on 'TARGET' values
appData_df.groupby('TARGET').sum()
# Out:
#          SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT  \
# TARGET
# 0       78655893854        116734      4.779590e+10  1.703602e+11
# 1        6887675594         11514      4.111312e+09  1.384685e+10
#
#          AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# TARGET
# 0       7.678749e+09     1.534003e+11                 5942.256975
# 1       6.574093e+08     1.213792e+10                  474.917032
#
#           DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  ...  \
# TARGET                                                  ...
# 0       4.562037e+09   1.969440e+10       1.421894e+09  ...
# 1       3.695159e+08   1.131705e+09       1.113929e+08  ...
#
#         LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# TARGET
# 0                             11447                   21100
# 1                              1056                    2939
#
#         REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# TARGET
# 0                        63347                    49712
# 1                         7520                     5503
#
#         OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# TARGET
# 0                       398816.0                   39198.0
# 1                        37088.0                    4759.0
#
#         OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# TARGET
# 0                       394078.0                   27237.0
# 1                        36630.0                    3427.0
#
#         DAYS_LAST_PHONE_CHANGE       Age
# TARGET
# 0                 2.760113e+08  12357088
# 1                 2.007838e+07    999950
#
# [2 rows x 27 columns]

# %%
###### Target Distribution

plt.figure(figsize=(12, 7))
plt.title("Distribution of Target variable (1 - Client with payment diffculties 0 - all other cases)", fontsize=14);

targetVal = appData_df["TARGET"].value_counts()

targetVal.plot(kind='pie', autopct='%1.1f%%', startangle=240, fontsize=16)
plt.show()

# %% [markdown]
# ### Observation :
#
# - As can be seen distribution of data **people having diffculty with repayment on loan is compartively less than people who dont have any diifuclties**.
# - Precisely **92%** people do not face any diffcultiies while **8%** faces payment diffculties

# %% [markdown]
# #### <font color = maroon> 2.8 Performing univariate anlysis on Target values </font>

# %%
appData_df_0 = appData_df[appData_df["TARGET"]==0]
appData_df_1 = appData_df[appData_df["TARGET"]==1]

# %%
# generic method to show univariate analysis against TARGET 0 dataset & TARGET 1 dataset

def plotGraph(column):
    plt.figure(figsize=(18,9))
    plt.subplot(1, 2, 1)
    sns.countplot(column, data=appData_df_0)
    plt.title('Distribution for Non-Defaulters', fontsize=14)
    plt.xlabel(column)
    plt.xticks(rotation=90)
    plt.subplot(1, 2, 2)
    sns.countplot(column, data=appData_df_1)
    plt.title('Distribution for Defaulters', fontsize=14)
    plt.xlabel(column)
    plt.xticks(rotation=90)
    plt.show()

# %%
plotGraph('NAME_FAMILY_STATUS')

# %%
plotGraph('CODE_GENDER')

# %%
plotGraph('INCOME_GROUP')

# %%
plotGraph('Age_Group')

# %%
plotGraph('NAME_TYPE_SUITE')

# %%
plotGraph('NAME_INCOME_TYPE')

# %%
plotGraph('NAME_FAMILY_STATUS')

# %%
plotGraph('NAME_TYPE_SUITE')

# %%
plotGraph('NAME_HOUSING_TYPE')

# %%
plotGraph('OCCUPATION_TYPE')

# %%
plotGraph('ORGANIZATION_TYPE')

# %% [markdown]
# ### Observations
#
# - People having FAMILY_STATUS as **Married** have relatively **lesser probability** of being a **Defaulter**  as compared to others.
# - **MALES** have relatively higher probability being a Defaulter comapared to **Females**
# - **Bussinessman & Students** never fall in the category of being a Defaulter.
# - **Young Adults** or people in the age group between **20 and 39** have relatively higer probability of being a Defaulter tahn other age groups.
# - **Self Employed** people have relatively higer probability of being a defaulter.

# %% [markdown]
# #### <font color = maroon> 2.9 Performing Segmented univariate anlysis on Target values </font>

# %%
def segmented_univariate(x, y):
    plt.figure(figsize=(15, 7))
    # subplot 1: statistic=mean
    plt.subplot(1, 2, 1)
    plt.xticks(rotation=90)
    sns.barplot(x=x, y=y, data=appData_df_0, estimator =np.median)
    plt.title("NON-DEFAULTERS")
    # subplot 2: statistic=median
    plt.subplot(1, 2, 2)
    plt.xticks(rotation=90)
    sns.barplot(x=x, y=y, data=appData_df_1, estimator =np.median)
    plt.title("DEFAULTERS")
    plt.show()
    
segmented_univariate('CODE_GENDER', 'DAYS_LAST_PHONE_CHANGE')

# %%
segmented_univariate('CODE_GENDER', 'DAYS_EMPLOYED')

# %% [markdown]
# ### Observations
#
# - **Males who are defaulter have a higher tendency to change their phones** compared to that of females.
# - **Males** with end up being a defaulter also have been a trend of job change recently comapred to that of females.

# %% [markdown]
# #### <font color = maroon> 2.10 Performing Bivariate and Multivariate Analysis </font>

# %% [markdown]
# ##### <font color = maroon> 2.10.1 Numeric to Numeric Analysus for Non-Defaulters and Defaulters  </font>

# %%
# plotting pair plots for NON-DEFAULTERS paramters

pair = appData_df_0[['AMT_CREDIT', 'AMT_ANNUITY', 'AMT_INCOME_TOTAL', 'AMT_GOODS_PRICE', 'Age', 'DAYS_LAST_PHONE_CHANGE']]
sns.pairplot(pair)

plt.show()

# %%
# plotting pair plots for DEFAULTERS
pair = appData_df_1[['AMT_CREDIT', 'AMT_ANNUITY', 'AMT_INCOME_TOTAL', 'AMT_GOODS_PRICE', 'Age', 'DAYS_LAST_PHONE_CHANGE']]
sns.pairplot(pair)

plt.show()

# %%
# finding correlation in NON-DEFAULTERS dataset

corr_nonDefaulter = appData_df_0[['AMT_GOODS_PRICE','AMT_INCOME_TOTAL','AMT_ANNUITY','DAYS_EMPLOYED','Age',
         'AMT_CREDIT','CNT_FAM_MEMBERS', 'CNT_CHILDREN', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
              'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE','REGION_RATING_CLIENT','REGION_POPULATION_RELATIVE',
              'REGION_RATING_CLIENT_W_CITY','REG_REGION_NOT_LIVE_REGION','REG_REGION_NOT_WORK_REGION',
              'LIVE_REGION_NOT_WORK_REGION','REG_CITY_NOT_LIVE_CITY','LIVE_CITY_NOT_WORK_CITY']].corr(method = 'pearson')

unstacked_nonDefaulter = corr_nonDefaulter.unstack().drop_duplicates()

u_nD = unstacked_nonDefaulter.sort_values(kind="quicksort", ascending = False).head(50)

# %%
# printing top 10 correlation in non-Defaulter dataset
u_nD.iloc[1:11]
# Out:
# OBS_30_CNT_SOCIAL_CIRCLE    OBS_60_CNT_SOCIAL_CIRCLE       0.998508
# AMT_GOODS_PRICE             AMT_CREDIT                     0.987022
# REGION_RATING_CLIENT        REGION_RATING_CLIENT_W_CITY    0.950149
# CNT_FAM_MEMBERS             CNT_CHILDREN                   0.878571
# REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION    0.861861
# DEF_30_CNT_SOCIAL_CIRCLE    DEF_60_CNT_SOCIAL_CIRCLE       0.859332
# AMT_GOODS_PRICE             AMT_ANNUITY                    0.776421
# AMT_ANNUITY                 AMT_CREDIT                     0.771297
# DAYS_EMPLOYED               Age                            0.626028
# REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION     0.446101
# dtype: float64

# %%
# finding correlation in DEFAULTERS dataset

corr_Defaulter = appData_df_1[['AMT_GOODS_PRICE','AMT_INCOME_TOTAL','AMT_ANNUITY','DAYS_EMPLOYED','Age',
         'AMT_CREDIT','CNT_FAM_MEMBERS', 'CNT_CHILDREN', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
              'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE','REGION_RATING_CLIENT','REGION_POPULATION_RELATIVE',
              'REGION_RATING_CLIENT_W_CITY','REG_REGION_NOT_LIVE_REGION','REG_REGION_NOT_WORK_REGION',
              'LIVE_REGION_NOT_WORK_REGION','REG_CITY_NOT_LIVE_CITY','LIVE_CITY_NOT_WORK_CITY']].corr(method = 'pearson')


unstacked_Defaulter = corr_Defaulter.unstack().drop_duplicates()

u_D = unstacked_Defaulter.sort_values(kind="quicksort", ascending = False).head(50)

# %%
# printing top 10 correlation in Defaulter dataset
u_D.iloc[1:11]
# Out:
# OBS_30_CNT_SOCIAL_CIRCLE    OBS_60_CNT_SOCIAL_CIRCLE       0.998269
# AMT_GOODS_PRICE             AMT_CREDIT                     0.982783
# REGION_RATING_CLIENT        REGION_RATING_CLIENT_W_CITY    0.956637
# CNT_FAM_MEMBERS             CNT_CHILDREN                   0.885484
# DEF_30_CNT_SOCIAL_CIRCLE    DEF_60_CNT_SOCIAL_CIRCLE       0.868994
# REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION    0.847885
# AMT_GOODS_PRICE             AMT_ANNUITY                    0.752295
# AMT_ANNUITY                 AMT_CREDIT                     0.752195
# DAYS_EMPLOYED               Age                            0.582441
# REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION     0.497937
# dtype: float64

# %%
# finding top 10 inverse correlation
u_ID = unstacked_Defaulter.sort_values(kind="quicksort", ascending = True).head(50)

# %%
# printing top 10 correlation in Defaulter dataset with inverse relations
u_ID.iloc[1:11]
# Out:
# REGION_RATING_CLIENT         REGION_POPULATION_RELATIVE    -0.443236
# Age                          CNT_CHILDREN                  -0.259222
#                              CNT_FAM_MEMBERS               -0.203403
# DAYS_EMPLOYED                LIVE_CITY_NOT_WORK_CITY       -0.198484
#                              CNT_CHILDREN                  -0.192864
#                              CNT_FAM_MEMBERS               -0.186515
# Age                          REG_CITY_NOT_LIVE_CITY        -0.161921
#                              LIVE_CITY_NOT_WORK_CITY       -0.123556
# REGION_RATING_CLIENT         LIVE_REGION_NOT_WORK_REGION   -0.117079
# REGION_RATING_CLIENT_W_CITY  LIVE_REGION_NOT_WORK_REGION   -0.111948
# dtype: float64

# %% [markdown]
# ### Observations
#
# - **AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE'** seems to have a linear relation among each other.
# - **HIGH correlation** were found among following parameters for both Defaulters & Non - Defaulters category
#   - OBS_30_CNT_SOCIAL_CIRCLE & OBS_60_CNT_SOCIAL_CIRCLE
#   - AMT_GOODS_PRICE & AMT_CREDIT
#   - REGION_RATING_CLIENT & REGION_RATING_CLIENT_W_CITY

# %% [markdown]
# ##### <font color = maroon> 2.10.2 Numeric to Categorical columna Analysus for Non-Defaulters and Defaulters  </font>

# %%
# Numeric value AMT_CREDIT comparison against Category "NAME_HOUSING_TYPE"

plt.figure(figsize=(15, 7))
appData_df_1.groupby("NAME_HOUSING_TYPE")["AMT_CREDIT"].mean().plot.bar()
plt.show()

# %%
# Numeric value DAYS_LAST_PHONE_CHANGE comparison against Category "OCCUPATION_TYPE"

plt.figure(figsize=(15, 7))
appData_df_1.groupby("OCCUPATION_TYPE")["DAYS_LAST_PHONE_CHANGE"].median().plot.bar()
plt.show()

# %% [markdown]
# #### It can be seen IT staff & Cleaning Staff have higher tendency to change PHONE in recent days when being a defaulter.
# #### Also Housing Type of people in Defaulter category is higher when they are in Office Appartments

# %% [markdown]
# ### Observations
#
# - Among **Defaulters** it is seen that **IT Staff & Cleaning Staff** have a atendency to change their phone.
# - Also **Hosuing Type** in terms of Amount being credited to people are generally with **Office appparments**

# %% [markdown]
# ### <font color = maroon> 3. Reading and cleaning the data from Previous Application</font>

# %%
# reading the previous application information
prevApp_df = pd.read_csv('previous_application.csv')

# %%
# checking the shape of previous application data
prevApp_df.shape
# Out:
# (1670214, 37)

# %%
#checking information of all fields in previous application
prevApp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
#  12  RATE_DOWN_PAYMENT            774370 non-null   float64
#  13  RATE_INTEREST_PRIMARY        5951 non-null     float64
#  14  RATE_INTEREST_PRIVILEGED     5951 non-null     float64
#  15  NAME_CASH_LOAN_PURPOSE       1670214 non-null  object
#  16  NAME_CONTRACT_STATUS         1670214 non-null  object
#  17  DAYS_DECISION                1670214 non-null  int64
#  18  NAME_PAYMENT_TYPE            1670214 non-null  object
#  19  CODE_REJECT_REASON           1670214 non-null  object
#  20  NAME_TYPE_SUITE              849809 non-null   object
#  21  NAME_CLIENT_TYPE             1670214 non-null  object
#  22  NAME_GOODS_CATEGORY          1670214 non-null  object
#  23  NAME_PORTFOLIO               1670214 non-null  object
#  24  NAME_PRODUCT_TYPE            1670214 non-null  object
#  25  CHANNEL_TYPE                 1670214 non-null  object
#  26  SELLERPLACE_AREA             1670214 non-null  int64
#  27  NAME_SELLER_INDUSTRY         1670214 non-null  object
#  28  CNT_PAYMENT                  1297984 non-null  float64
#  29  NAME_YIELD_GROUP             1670214 non-null  object
#  30  PRODUCT_COMBINATION          1669868 non-null  object
#  31  DAYS_FIRST_DRAWING           997149 non-null   float64
#  32  DAYS_FIRST_DUE               997149 non-null   float64
#  33  DAYS_LAST_DUE_1ST_VERSION    997149 non-null   float64
#  34  DAYS_LAST_DUE                997149 non-null   float64
#  35  DAYS_TERMINATION             997149 non-null   float64
#  36  NFLAG_INSURED_ON_APPROVAL    997149 non-null   float64
# dtypes: float64(15), int64(6), object(16)
# memory usage: 471.5+ MB

# %%
# sdescribeing numeric fields of previous application
prevApp_df.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# 50%    8.054100e+04      1.638000e+03     1.123200e+05
# 75%    2.164185e+05      7.740000e+03     2.340000e+05
# max    6.905160e+06      3.060045e+06     6.905160e+06
#
#        HOUR_APPR_PROCESS_START  NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  \
# count             1.670214e+06            1.670214e+06      774370.000000
# mean              1.248418e+01            9.964675e-01           0.079637
# std               3.334028e+00            5.932963e-02           0.107823
# min               0.000000e+00            0.000000e+00          -0.000015
# 25%               1.000000e+01            1.000000e+00           0.000000
# 50%               1.200000e+01            1.000000e+00           0.051605
# 75%               1.500000e+01            1.000000e+00           0.108909
# max               2.300000e+01            1.000000e+00           1.000000
#
#        ...  RATE_INTEREST_PRIVILEGED  DAYS_DECISION  SELLERPLACE_AREA  \
# count  ...               5951.000000   1.670214e+06      1.670214e+06
# mean   ...                  0.773503  -8.806797e+02      3.139511e+02
# std    ...                  0.100879   7.790997e+02      7.127443e+03
# min    ...                  0.373150  -2.922000e+03     -1.000000e+00
# 25%    ...                  0.715645  -1.300000e+03     -1.000000e+00
# 50%    ...                  0.835095  -5.810000e+02      3.000000e+00
# 75%    ...                  0.852537  -2.800000e+02      8.200000e+01
# max    ...                  1.000000  -1.000000e+00      4.000000e+06
#
#         CNT_PAYMENT  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# count  1.297984e+06       997149.000000   997149.000000
# mean   1.605408e+01       342209.855039    13826.269337
# std    1.456729e+01        88916.115834    72444.869708
# min    0.000000e+00        -2922.000000    -2892.000000
# 25%    6.000000e+00       365243.000000    -1628.000000
# 50%    1.200000e+01       365243.000000     -831.000000
# 75%    2.400000e+01       365243.000000     -411.000000
# max    8.400000e+01       365243.000000   365243.000000
#
#        DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# count              997149.000000  997149.000000     997149.000000
# mean                33767.774054   76582.403064      81992.343838
# std                106857.034789  149647.415123     153303.516729
# min                 -2801.000000   -2889.000000      -2874.000000
# 25%                 -1242.000000   -1314.000000      -1270.000000
# 50%                  -361.000000    -537.000000       -499.000000
# 75%                   129.000000     -74.000000        -44.000000
# max                365243.000000  365243.000000     365243.000000
#
#        NFLAG_INSURED_ON_APPROVAL
# count              997149.000000
# mean                    0.332570
# std                     0.471134
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     1.000000
#
# [8 rows x 21 columns]

# %%
# all negative values for DAY_* columns to be replaced with abs() values for easier analysis
column_list=[]
for i in prevApp_df.columns:
    if  i.startswith('DAYS_'):
        column_list.append(i)
        
        
prevApp_df[column_list]= abs(prevApp_df[column_list])

# %%
# replacing field values "XNA" & "XNP" with null values
prevApp_df=prevApp_df.replace('XNA', np.NaN)
prevApp_df=prevApp_df.replace('XAP', np.NaN)

# %%
#checking for all null values count
prevApp_df.isnull().sum().sort_values(ascending = False)
# Out:
# RATE_INTEREST_PRIMARY          1664263
# RATE_INTEREST_PRIVILEGED       1664263
# NAME_CASH_LOAN_PURPOSE         1600579
# CODE_REJECT_REASON             1358337
# NAME_PRODUCT_TYPE              1063666
# NAME_GOODS_CATEGORY             950809
# AMT_DOWN_PAYMENT                895844
# RATE_DOWN_PAYMENT               895844
# NAME_SELLER_INDUSTRY            855720
# NAME_TYPE_SUITE                 820405
# NFLAG_INSURED_ON_APPROVAL       673065
# DAYS_LAST_DUE                   673065
# DAYS_LAST_DUE_1ST_VERSION       673065
# DAYS_FIRST_DUE                  673065
# DAYS_FIRST_DRAWING              673065
# DAYS_TERMINATION                673065
# NAME_PAYMENT_TYPE               627384
# NAME_YIELD_GROUP                517215
# AMT_GOODS_PRICE                 385515
# AMT_ANNUITY                     372235
# CNT_PAYMENT                     372230
# NAME_PORTFOLIO                  372230
# NAME_CLIENT_TYPE                  1941
# NAME_CONTRACT_TYPE                 346
# PRODUCT_COMBINATION                346
# AMT_CREDIT                           1
# SK_ID_CURR                           0
# AMT_APPLICATION                      0
# HOUR_APPR_PROCESS_START              0
# WEEKDAY_APPR_PROCESS_START           0
# FLAG_LAST_APPL_PER_CONTRACT          0
# NFLAG_LAST_APPL_IN_DAY               0
# SELLERPLACE_AREA                     0
# CHANNEL_TYPE                         0
# NAME_CONTRACT_STATUS                 0
# DAYS_DECISION                        0
# SK_ID_PREV                           0
# dtype: int64

# %%
# generic method for plotting distributions of parameters in previous application dataframe

def checkDistributionsForPrev(param):
    plt.figure(figsize=(14, 10))
    plt.title('Distribution of Applicants in terms of their ' + param + ' in previous application', fontsize=18)
    sortedData = prevApp_df[param].value_counts().sort_values()
    sortedData.plot(kind='barh')
    plt.show()

# %%
checkDistributionsForPrev('PRODUCT_COMBINATION')

# %%
checkDistributionsForPrev('CHANNEL_TYPE')

# %%
checkDistributionsForPrev('CODE_REJECT_REASON')

# %%
checkDistributionsForPrev('NAME_CONTRACT_STATUS')

# %%
checkDistributionsForPrev('NAME_CASH_LOAN_PURPOSE')

# %%
checkDistributionsForPrev('NAME_CONTRACT_TYPE')

# %% [markdown]
# ### Observations
#
# - **Cash & Pos household with Interest** have higer distribution in Product Combination
# - **Cash loans & Consumer Loans** have higher distribution of **Contract Type** in previous applications.
# - **Maximum loans** were taken previously with intention of **repairs**
# - Distribution of Contract Status from previous applications can be seen as **Approved > Cancelled > Refused > Unused offers**
# - Loans had rejection rate with the **code  HC**
# - Maximum distribution for **PAYMENT_TYPE is through cash throughbank**

# %% [markdown]
# ### <font color = maroon> 4. Analysis after merging Previous Application and Application Data</font>

# %%
# merging application data & previous application on SK_ID_CURR
mergedData = appData_df.merge(prevApp_df,on='SK_ID_CURR', how='inner')

# %%
# checking for null values counts after merging both the dataset
mergedData.isnull().sum().sort_values(ascending = False)
# Out:
# RATE_INTEREST_PRIMARY          1408910
# RATE_INTEREST_PRIVILEGED       1408910
# NAME_CASH_LOAN_PURPOSE         1354288
# CODE_REJECT_REASON             1149911
# NAME_PRODUCT_TYPE               900053
#                                 ...
# REG_CITY_NOT_LIVE_CITY               0
# LIVE_REGION_NOT_WORK_REGION          0
# REG_REGION_NOT_WORK_REGION           0
# REG_REGION_NOT_LIVE_REGION           0
# SK_ID_CURR                           0
# Length: 76, dtype: int64

# %%
#rechecking the shape of merged dataset
mergedData.shape
# Out:
# (1413701, 76)

# %%
#checking the values of first row for merged data
mergedData.head(1)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE_x CODE_GENDER  CNT_CHILDREN  \
# 0      100002       1           Cash loans           M             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  AMT_GOODS_PRICE_x  \
# 0          202500.0      406597.5        24700.5           351000.0
#
#   NAME_TYPE_SUITE_x  ... NAME_SELLER_INDUSTRY CNT_PAYMENT NAME_YIELD_GROUP  \
# 0     Unaccompanied  ...      Auto technology        24.0       low_normal
#
#        PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# 0  POS other with interest            365243.0           565.0
#
#    DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0                      125.0           25.0              17.0
#
#   NFLAG_INSURED_ON_APPROVAL
# 0                       0.0
#
# [1 rows x 76 columns]

# %%
# checking information of all columns 
mergedData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413701 entries, 0 to 1413700
# Data columns (total 76 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   SK_ID_CURR                    1413701 non-null  int64
#  1   TARGET                        1413701 non-null  int64
#  2   NAME_CONTRACT_TYPE_x          1413701 non-null  object
#  3   CODE_GENDER                   1413701 non-null  object
#  4   CNT_CHILDREN                  1413701 non-null  int64
#  5   AMT_INCOME_TOTAL              1413701 non-null  float64
#  6   AMT_CREDIT_x                  1413701 non-null  float64
#  7   AMT_ANNUITY_x                 1413701 non-null  float64
#  8   AMT_GOODS_PRICE_x             1413701 non-null  float64
#  9   NAME_TYPE_SUITE_x             1413701 non-null  object
#  10  NAME_INCOME_TYPE              1413701 non-null  object
#  11  NAME_EDUCATION_TYPE           1413701 non-null  object
#  12  NAME_FAMILY_STATUS            1413701 non-null  object
#  13  NAME_HOUSING_TYPE             1413701 non-null  object
#  14  REGION_POPULATION_RELATIVE    1413701 non-null  float64
#  15  DAYS_BIRTH                    1413701 non-null  float64
#  16  DAYS_EMPLOYED                 1413701 non-null  float64
#  17  DAYS_REGISTRATION             1413701 non-null  float64
#  18  DAYS_ID_PUBLISH               1413701 non-null  float64
#  19  OCCUPATION_TYPE               1413701 non-null  object
#  20  CNT_FAM_MEMBERS               1413701 non-null  float64
#  21  REGION_RATING_CLIENT          1413701 non-null  int64
#  22  REGION_RATING_CLIENT_W_CITY   1413701 non-null  int64
#  23  WEEKDAY_APPR_PROCESS_START_x  1413701 non-null  object
#  24  HOUR_APPR_PROCESS_START_x     1413701 non-null  int64
#  25  REG_REGION_NOT_LIVE_REGION    1413701 non-null  int64
#  26  REG_REGION_NOT_WORK_REGION    1413701 non-null  int64
#  27  LIVE_REGION_NOT_WORK_REGION   1413701 non-null  int64
#  28  REG_CITY_NOT_LIVE_CITY        1413701 non-null  int64
#  29  REG_CITY_NOT_WORK_CITY        1413701 non-null  int64
#  30  LIVE_CITY_NOT_WORK_CITY       1413701 non-null  int64
#  31  ORGANIZATION_TYPE             1413701 non-null  object
#  32  OBS_30_CNT_SOCIAL_CIRCLE      1410555 non-null  float64
#  33  DEF_30_CNT_SOCIAL_CIRCLE      1410555 non-null  float64
#  34  OBS_60_CNT_SOCIAL_CIRCLE      1410555 non-null  float64
#  35  DEF_60_CNT_SOCIAL_CIRCLE      1410555 non-null  float64
#  36  DAYS_LAST_PHONE_CHANGE        1413701 non-null  float64
#  37  Age                           1413701 non-null  int32
#  38  INCOME_GROUP                  1413701 non-null  category
#  39  Age_Group                     1413701 non-null  category
#  40  SK_ID_PREV                    1413701 non-null  int64
#  41  NAME_CONTRACT_TYPE_y          1413388 non-null  object
#  42  AMT_ANNUITY_y                 1106483 non-null  float64
#  43  AMT_APPLICATION               1413701 non-null  float64
#  44  AMT_CREDIT_y                  1413700 non-null  float64
#  45  AMT_DOWN_PAYMENT              664161 non-null   float64
#  46  AMT_GOODS_PRICE_y             1094176 non-null  float64
#  47  WEEKDAY_APPR_PROCESS_START_y  1413701 non-null  object
#  48  HOUR_APPR_PROCESS_START_y     1413701 non-null  int64
#  49  FLAG_LAST_APPL_PER_CONTRACT   1413701 non-null  object
#  50  NFLAG_LAST_APPL_IN_DAY        1413701 non-null  int64
#  51  RATE_DOWN_PAYMENT             664161 non-null   float64
#  52  RATE_INTEREST_PRIMARY         4791 non-null     float64
#  53  RATE_INTEREST_PRIVILEGED      4791 non-null     float64
#  54  NAME_CASH_LOAN_PURPOSE        59413 non-null    object
#  55  NAME_CONTRACT_STATUS          1413701 non-null  object
#  56  DAYS_DECISION                 1413701 non-null  float64
#  57  NAME_PAYMENT_TYPE             890741 non-null   object
#  58  CODE_REJECT_REASON            263790 non-null   object
#  59  NAME_TYPE_SUITE_y             719029 non-null   object
#  60  NAME_CLIENT_TYPE              1412158 non-null  object
#  61  NAME_GOODS_CATEGORY           616492 non-null   object
#  62  NAME_PORTFOLIO                1106488 non-null  object
#  63  NAME_PRODUCT_TYPE             513648 non-null   object
#  64  CHANNEL_TYPE                  1413701 non-null  object
#  65  SELLERPLACE_AREA              1413701 non-null  int64
#  66  NAME_SELLER_INDUSTRY          698379 non-null   object
#  67  CNT_PAYMENT                   1106488 non-null  float64
#  68  NAME_YIELD_GROUP              984503 non-null   object
#  69  PRODUCT_COMBINATION           1413388 non-null  object
#  70  DAYS_FIRST_DRAWING            852595 non-null   float64
#  71  DAYS_FIRST_DUE                852595 non-null   float64
#  72  DAYS_LAST_DUE_1ST_VERSION     852595 non-null   float64
#  73  DAYS_LAST_DUE                 852595 non-null   float64
#  74  DAYS_TERMINATION              852595 non-null   float64
#  75  NFLAG_INSURED_ON_APPROVAL     852595 non-null   float64
# dtypes: category(2), float64(31), int32(1), int64(16), object(26)
# memory usage: 806.2+ MB

# %% [markdown]
# #### <font color = maroon> 4.1. Finding Correlations for Defaulter with various parameters</font>

# %%
#finding corrleation between NAME_CONTRACT_STATUS & NAME_EDUCATION_TYPE

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["NAME_EDUCATION_TYPE"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %%
#finding corrleation between NAME_CONTRACT_STATUS & NAME_INCOME_TYPE

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["NAME_INCOME_TYPE"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %%
#finding corrleation between NAME_CONTRACT_STATUS & INCOME_GROUP

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["INCOME_GROUP"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %%
#finding corrleation between NAME_CONTRACT_STATUS & Age_Group

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["Age_Group"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %%
#finding corrleation between NAME_CONTRACT_STATUS & NAME_FAMILY_STATUS

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["NAME_FAMILY_STATUS"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %%
#finding corrleation between NAME_CONTRACT_STATUS & OCCUPATION_TYPE

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["OCCUPATION_TYPE"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %%
#finding corrleation between NAME_CONTRACT_STATUS & NAME_CASH_LOAN_PURPOSE

plt.figure(figsize=[15,5])
table = pd.pivot_table(data=mergedData, index="NAME_CONTRACT_STATUS", values="TARGET",columns=["NAME_CASH_LOAN_PURPOSE"])
sns.heatmap(data=table,cmap="Blues",annot=True)
plt.show()

# %% [markdown]
# ### Observations
#
# - Cash loan of with purpose of **'Money for third person', 'Refusal to name the goal'** have more probability of being a defaulter
# - **Low skilled laborers & IT Staff** have more probability of being a defaulter
# - People who end up having  a **Civil marriage** have relatively higher probability of being a defaulter.
# - **Females on MATERNITY LEAVE** generally end up being a defaulter
# - People with ***Academic degree* also end up being a defaulter
